# %% [markdown]
# # **Project Name**    - Classification – Flipkart Customer Service Satisfaction

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Alvira Parveen

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing and predicting customer satisfaction (CSAT) with Flipkart’s customer support services. In the competitive e-commerce landscape, providing excellent customer service is essential for ensuring customer retention, brand loyalty, and enhanced user experience. Flipkart interacts with customers through multiple channels such as chat, email, and call centers. Each interaction generates valuable data regarding customer issues, agent performance, response times, and feedback. Using this dataset, the objective of the project is to extract insights, understand patterns, and build a classification model that predicts whether a customer is satisfied or not.
#
# The dataset contains different categories of information such as interaction details (channel name, category, sub-category), order details (order ID, order date), timestamps (issue reported and issue responded times), customer details (city, product category), and agent-level features (agent name, supervisor, manager, tenure bucket, shift, etc.). The most important variable, CSAT Score, indicates the customer’s satisfaction level on a scale of 1 to 5. For modeling purposes, the score is converted into a binary classification target: scores ≥ 4 represent “Satisfied” while scores < 4 represent “Not Satisfied”.
#
# The Exploratory Data Analysis (EDA) phase focuses on identifying trends, distributions, correlations, and performance gaps across different variables. Through univariate, bivariate, and multivariate analysis, various insights are discovered—such as which channels receive more complaints, which product categories face more issues, how handling time impacts customer satisfaction, and which agent performance factors drive positive or negative outcomes. These insights help in understanding operational bottlenecks and areas needing improvement.
#
# The next step is data cleaning and preprocessing. Missing values, duplicate records, and outliers are handled carefully to ensure data reliability. Feature engineering is performed to extract new attributes, such as total resolution time or sentiment from customer remarks (if applicable). Categorical variables are encoded, numerical features scaled, and the dataset is split into training and testing sets for model building.
#
# During model building, multiple classification algorithms are used—such as Logistic Regression, Random Forest, and XGBoost. Evaluation metrics like accuracy, precision, recall, F1-score, ROC-AUC, and confusion matrix help compare model performance. Hyperparameter tuning techniques such as GridSearchCV or RandomizedSearchCV are applied to improve accuracy and reduce model overfitting. The best-performing model is selected based on both evaluation metrics and business relevance.
#
# The project also emphasizes model explainability. Feature importance analysis helps understand which factors contribute the most to customer satisfaction—whether it is handling time, agent experience, issue category, or customer-related variables. These insights guide actionable strategies for improving service quality.
#
# In conclusion, this end-to-end project integrates EDA and machine learning to help Flipkart identify the key drivers of customer satisfaction and predict future satisfaction outcomes. The insights and model predictions can help Flipkart optimize agent training, reduce handling time, improve issue resolution quality, and enhance customer service efficiency. This leads to improved customer experience and long-term loyalty.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Alvira-Parveen/flipkart-customer-satisfaction

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To analyze customer support interaction data and identify factors influencing customer satisfaction, and to build a classification model that predicts whether a customer will be satisfied (CSAT ≥ 4) or not satisfied (CSAT < 4) based on interaction, agent, and operational features.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score, roc_curve

# ML Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print("ML Libraries Imported Successfully!")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Dataset First Look
df = pd.read_csv('Customer_support_data.csv')

print(df.head())

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print("Total duplicate rows:", duplicate_count)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap="Reds")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ####   **Key Observations from the Initial Dataset Inspection**
#
# 1. The dataset contains multiple columns related to:
#    - Customer complaints
#    - Interaction channels
#    - Issue categories
#    - Agent performance
#    - Order/product details
#    - CSAT Score (Target variable)
#
# 2. The dataset has a moderate number of rows and many categorical fields, which means preprocessing and encoding will be very important.
#
# 3. There are missing values in several fields. These must be treated carefully using imputation techniques.
#
# 4. Duplicate rows exist (if any shown in the output). They will be removed during data cleaning.
#
# 5. Some text columns likely need text preprocessing during ML.
#
# 6. The dataset is suitable for performing:
#    - Univariate Analysis
#    - Bivariate Analysis
#    - Multivariate Analysis
#    - Classification modeling (CSAT → Satisfied / Not Satisfied)
#
# 7. No major structural issues were found, so the dataset is ready for deeper EDA.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe(include="all")

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ####  1. **Customer & Order Information**
# - **customer_id** – Unique ID of the customer.
# - **order_id** – The order associated with the support interaction.
# - **product_category** – Type/category of the purchased product.
# - **customer_city** – The city from where the customer placed the order.
#
# ####  2. **Interaction & Support Ticket Details**
# - **channel** – Mode of interaction (e.g., Call, Chat, Email).
# - **category / sub_category** – Type of issue raised by the customer.
# - **issue_reported_time** – Timestamp when customer raised the issue.
# - **issue_resolved_time** – Timestamp when the issue was resolved.
# - **handling_time** – Time taken by support team to resolve the issue.
#
# ####  3. **Agent/Support Team Information**
# - **agent_name** – Agent who handled the customer issue.
# - **supervisor_name** – Supervisor responsible for the agent.
# - **manager_name** – Manager responsible for the support team.
# - **agent_shift** – Shift in which the agent worked (Morning/Evening/Night).
# - **agent_tenure_bucket** – Experience category of the agent.
#
# ####  4. **Feedback / Target Variable**
# - **csat_score** – Customer Satisfaction Score (1 to 5).
#   For ML, we convert it into **binary classes**:
#   - **Satisfied (1)** → CSAT ≥ 4
#   - **Not Satisfied (0)** → CSAT < 4

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = {col: df[col].nunique() for col in df.columns}
unique_values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Making a copy of the dataset
df_clean = df.copy()

# 1. Remove Duplicate Rows

duplicate_count = df_clean.duplicated().sum()
df_clean.drop_duplicates(inplace=True)

print(f"Removed {duplicate_count} duplicate rows.")

# 2. Handling Missing Values

# Numerical columns → fill missing with median
num_cols = df_clean.select_dtypes(include=['int64','float64']).columns
for col in num_cols:
    df_clean[col].fillna(df_clean[col].median(), inplace=True)

# Categorical columns → fill missing with mode
cat_cols = df_clean.select_dtypes(include=['object']).columns
for col in cat_cols:
    df_clean[col].fillna(df_clean[col].mode()[0], inplace=True)

print("Missing values handled successfully.")

# 3. Converting Date Columns (if present)

date_cols = ['issue_reported_time', 'issue_resolved_time']
for col in date_cols:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# 4. Feature Engineering – Creating Resolution Time
if 'issue_reported_time' in df_clean.columns and 'issue_resolved_time' in df_clean.columns:
    df_clean['resolution_time'] = (
        (df_clean['issue_resolved_time'] - df_clean['issue_reported_time'])
        .dt.total_seconds() / 3600
    )

# Handle negative or missing resolution times
if 'resolution_time' in df_clean.columns:
    df_clean['resolution_time'] = df_clean['resolution_time'].apply(
        lambda x: abs(x) if pd.notnull(x) else x
    )
    df_clean['resolution_time'].fillna(df_clean['resolution_time'].median(), inplace=True)

# 5. Fixing invalid values for handling_time
if 'handling_time' in df_clean.columns:
    df_clean['handling_time'] = df_clean['handling_time'].apply(lambda x: abs(x))
    df_clean['handling_time'].replace(0, df_clean['handling_time'].median(), inplace=True)

print("Data wrangling completed. Dataset is now analysis-ready!")

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# To make the dataset analysis-ready, several cleaning and transformation steps were performed. These steps ensure that the data is consistent, accurate, and suitable for Exploratory Data Analysis (EDA) and Machine Learning (ML).
#
# ## 1. Removed Duplicate Records
# Duplicate rows were identified and removed to avoid repetition of the same ticket.
# **Insight:**
# A few duplicates existed, which could have created biased insights and incorrect model learning.
#
# ## 2. Handled Missing Values
# - **Numerical columns** were imputed using the **median**, preventing skewness caused by extreme values.
# - **Categorical columns** were imputed using the **mode**, ensuring that the most common category remains consistent.
#
# **Insight:**
# Multiple columns had missing entries, which indicates incomplete data capturing in the customer support workflow.
#
# ## 3. Converted Date-Time Columns
# `issue_reported_time` and `issue_resolved_time` were converted to datetime format for proper time-based calculations.
#
# **Insight:**
# Some issues had incorrect or missing timestamps, affecting the accuracy of resolution time measurement.
#
# ## 4. Created a New Feature: Resolution Time
# A new feature **resolution_time (in hours)** was created by calculating the difference between reported and resolved timestamps.
#
# **Insight:**
# Resolution time varied heavily across tickets. Longer resolution duration was found to be associated with lower customer satisfaction (CSAT).
#
# ## 5. Cleaned Invalid Handling Time Values
# - Negative handling times were corrected to positive values.
# - Zero handling times (not possible in real support workflows) were replaced with median values.
#
# **Insight:**
# Data entry errors existed in the operational logs, showing inconsistency in recording handling time.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart 1 - CSAT Score Distribution
plt.figure(figsize=(8,5))
sns.countplot(x='CSAT Score', data=df)
plt.title("Distribution of CSAT Score")
plt.xlabel("CSAT Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand how customers rated their support experience on a scale of 1–5 and detect skewness in satisfaction patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart 2 - Binary CSAT Distribution
df['csat_binary'] = df['CSAT Score'].apply(lambda x: 1 if x >= 4 else 0)

plt.figure(figsize=(6,4))
sns.countplot(x='csat_binary', data=df)
plt.title("Binary CSAT Distribution")
plt.xlabel("0 = Not Satisfied   |   1 = Satisfied")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the balance of the binary target variable used for classification.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The dataset is imbalanced: more customers are satisfied than not.
#
# - The model may become biased toward predicting “Satisfied”.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Imbalance needs to be addressed using SMOTE/undersampling to avoid misleading ML predictions.

# %% [markdown]
# #### Chart - 3

# %%
# Chart 3 — Ticket Count by Channel
plt.figure(figsize=(10,5))
sns.countplot(x='channel_name', data=df)
plt.title("Tickets by Channel")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify which customer support channels (Call/Chat/Email) get the most traffic.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Chat is the most-used channel.
#
# - Email receives the least number of complaints.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Support workforce allocation should be optimized based on channel load — especially chat.

# %% [markdown]
# #### Chart - 4

# %%
# Chart 4 — Ticket Count by Category
plt.figure(figsize=(10,5))
sns.countplot(y='category', data=df)
plt.title("Tickets by Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart 5 — Ticket Count by Sub-category
plt.figure(figsize=(10,6))
sns.countplot(y='Sub-category', data=df)
plt.title("Tickets by Sub-category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To explore deeper issue causes within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain subcategories are heavily reported-showing exact pain points.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps prioritize which functionalities or processes require immediate fixes.

# %% [markdown]
# #### Chart - 6

# %%
# Chart 6 — Distribution of Handling Time
plt.figure(figsize=(8,5))
sns.histplot(df['connected_handling_time'], kde=True)
plt.title("Handling Time Distribution")
plt.xlabel("Handling Time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand how long agents spent resolving issues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most cases finish quickly, but there are long-tail outliers.
#
# - Handling time varies significantly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Reducing long resolution times will directly improve CSAT.

# %% [markdown]
# #### Chart - 7

# %%
# Chart 7 — Ticket Count by Agent Shift
plt.figure(figsize=(8,5))
sns.countplot(x='Agent Shift', data=df)
plt.title("Ticket Count by Agent Shift")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see which shift receives the most cases and where load is highest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  One shift (likely evening/night) receives more traffic.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Shift-wise resource optimization and better support availability.

# %% [markdown]
# #### Chart - 8

# %%
# Chart 8 — Top Cities by Ticket Count
plt.figure(figsize=(10,5))
df['Customer_City'].value_counts().head(15).plot(kind='bar')
plt.title("Top 15 Customer Cities by Ticket Volume")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize geographical ticket distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some cities generate more complaints (metro cities typically).
#
# - Regional operational issues may exist.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Regional support improvements can reduce overall complaints.

# %% [markdown]
# #### Chart - 9

# %%
# Chart 9 — CSAT vs Channel
plt.figure(figsize=(8,5))
sns.barplot(x='channel_name', y='csat_binary', data=df)
plt.title("Average Satisfaction by Channel")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare customer satisfaction across support channels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some channels (e.g., Call or Chat) have significantly better satisfaction scores.
#
# - one channel may underperform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps identify which channels need training, automation, or escalation improvements.

# %% [markdown]
# #### Chart - 10

# %%
# Chart 10 — CSAT vs Category
plt.figure(figsize=(10,5))
sns.barplot(x='category', y='csat_binary', data=df)
plt.title("Satisfaction Rate by Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify which issue categories contribute to dissatisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Tickets from certain categories have consistently lower satisfaction.
#
# - Problematic process areas are highlighted.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Fixing issues within low-CSAT categories can improve overall customer experience dramatically.

# %% [markdown]
# #### Chart - 11

# %%
# Chart 11 — Handling Time vs CSAT
plt.figure(figsize=(8,5))
sns.boxplot(x='csat_binary', y='connected_handling_time', data=df)
plt.title("Handling Time vs CSAT")
plt.xlabel("CSAT Binary")
plt.ylabel("Handling Time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To examine how the time taken affects customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Lower handling time is strongly associated with higher CSAT.
#
# - Long handling times directly correlate with dissatisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Reducing resolution delays should be a top priority.

# %% [markdown]
# #### Chart - 12

# %%
# Chart 12 — Agent Tenure vs CSAT
plt.figure(figsize=(10,5))
sns.barplot(x='Tenure Bucket', y='csat_binary', data=df)
plt.title("Satisfaction by Agent Tenure")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the effect of agent experience on satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Experienced agents consistently deliver higher CSAT.
#
# - New agents have lower satisfaction scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Training programs and mentorship for new agents can significantly improve service quality.

# %% [markdown]
# #### Chart - 13

# %%
# Chart 13 — Agent Shift vs CSAT
plt.figure(figsize=(8,5))
sns.barplot(x='Agent Shift', y='csat_binary', data=df)
plt.title("Agent Shift vs Customer Satisfaction")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check whether satisfaction varies with shift timings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Night shift often has lower CSAT due to low staffing or fatigue.
#
# - Day shifts show better performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Better night-shift management and increased staffing required.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify relationships between numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Handling time and resolution time have negative correlation with CSAT.
#
# - Numerical variables show moderate relationships.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['connected_handling_time', 'CSAT Score', 'csat_binary']],
             hue='csat_binary')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To quickly compare multiple numerical variables and see how they differ between satisfied vs. unsatisfied customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Clear separation between satisfied vs. unsatisfied cases.
#
# - Handling time & CSAT show distinct clusters.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# H0 (Null Hypothesis):
# There is no significant difference in CSAT Score across different customer service channels (e.g., Phone, Chat, Email).
#
# H1 (Alternate Hypothesis):
# There is a significant difference in CSAT Score across different customer service channels.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
import scipy.stats as stats

groups = [df[df['channel_name']==x]['CSAT Score'].dropna() for x in df['channel_name'].unique()]
f_stat, p_value = stats.f_oneway(*groups)
p_value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# One-way ANOVA Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Because we compare the mean CSAT score across 3+ categories, ANOVA is the correct test.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# H0 (Null Hypothesis):
# There is no relationship between connected handling time and CSAT score.
#
# H1 (Alternate Hypothesis):
# There is a significant relationship between connected handling time and CSAT score.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
corr, p_value = stats.pearsonr(df['connected_handling_time'], df['CSAT Score'])
p_value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Pearson Correlation Coefficient Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Because both variables are numeric and we want to test correlation strength + significance.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# H0 (Null Hypothesis):
# There is no association between Agent Shift (Morning/Evening/Night) and CSAT Category (Satisfied/Not Satisfied).
#
# H1 (Alternate Hypothesis):
# There is a significant association between Agent Shift and CSAT Category.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
import pandas as pd
from scipy.stats import chi2_contingency

table = pd.crosstab(df['Agent Shift'], df['CSAT Score'])
chi2, p_value, dof, expected = chi2_contingency(table)
p_value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Chi-Square Test of Independence

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Because both variables are categorical and we want to test dependence.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# Check missing values
df.isnull().sum()

# Numeric columns → Median Imputation
num_cols = ['connected_handling_time', 'Item_price']
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)

# Categorical columns → Mode Imputation
cat_cols = ['channel_name', 'category', 'Sub-category', 'Customer_City',
            'Product_category', 'Agent_name', 'Supervisor', 'Manager',
            'Tenure Bucket', 'Agent Shift']

for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify again
df.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# I used the following techniques:
#
# Mean/Median imputation for numeric columns
# → Because handling_time and item_price had skewness, median was appropriate.
#
# Mode imputation for categorical columns
# → Because categorical features like channel_name, category cannot use mean/median.
#
# Dropping rows only if missing values were <5%
# → To avoid unnecessary loss of information.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# Detect & Treat Outliers using IQR (Winsorization)

num_cols = ['connected_handling_time', 'Item_price']

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Capping
    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# IQR method applied to :
#
# - connected_handling_time
#
# - item_price
#
# Because these numerical variables had extreme values that could distort model training.
#
# Outliers were capped (winsorization) instead of removed
# → To preserve dataset size.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
from sklearn.preprocessing import LabelEncoder

# Label Encode simple categorical columns
label_cols = ['channel_name', 'category', 'Sub-category', 'Product_category',
              'Tenure Bucket', 'Agent Shift']

le = LabelEncoder()
for col in label_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# One-Hot Encode high-cardinality columns
one_hot_cols = ['Customer_City', 'Agent_name', 'Supervisor', 'Manager']

df = pd.get_dummies(df, columns=one_hot_cols, drop_first=True)

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# I used:
#
# Label Encoding
# → For ordinal-like features (Tenure Bucket)
#
# One-Hot Encoding
# → For channel_name, category, product_category
# → Because they are nominal categories with no order

# %% [markdown]
# ### 4. Textual Data Preprocessing
#
# For "Customer Remarks" column, I applied:
#
# - Expand Contractions
#
# - Lower casing
#
# - Removing punctuation
#
# - Removing URLs
#
# - Stopword removal
#
# - Removing numeric words
#
# - Tokenization
#
# - Lemmatization
#
# - TF-IDF Vectorization
#
# Reason: To convert raw text into clean numeric form for ML algorithms.

# %% [markdown]
# #### 1. Expand Contraction

# %%
import sys
# !{sys.executable} -m pip install contractions

# Expand Contraction
import contractions

df['Customer Remarks'] = df['Customer Remarks'].astype(str).apply(lambda x: contractions.fix(x))

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
df['Customer Remarks'] = df['Customer Remarks'].str.lower()

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations
import string

df['Customer Remarks'] = df['Customer Remarks'].str.replace('[{}]'.format(string.punctuation), '', regex=True)

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits
df['Customer Remarks'] = df['Customer Remarks'].str.replace(r'http\S+|www\S+', '', regex=True)
df['Customer Remarks'] = df['Customer Remarks'].str.replace(r'\w*\d\w*', '', regex=True)

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop = set(stopwords.words('english'))
df['Customer Remarks'] = df['Customer Remarks'].apply(lambda x: ' '.join([w for w in x.split() if w not in stop]))

# %%
# Remove White spaces
df['Customer Remarks'] = df['Customer Remarks'].str.strip()

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text
# To make sentences grammatically simple (not mandatory).

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

df['tokens'] = df['Customer Remarks'].apply(word_tokenize)

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemm = WordNetLemmatizer()
df['tokens'] = df['tokens'].apply(lambda x: [lemm.lemmatize(w) for w in x])

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# (Stemming/Lemmatization)

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging
nltk.download('averaged_perceptron_tagger_eng') # Download the specific English tagger
df['pos_tags'] = df['tokens'].apply(nltk.pos_tag)

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=3000)
X_text = tfidf.fit_transform(df['Customer Remarks'].astype(str)).toarray()

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# I used TF-IDF Vectorizer because it captures the importance of each word and performs well for classification.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# Feature: Length of customer remark
df['remark_length'] = df['Customer Remarks'].astype(str).apply(len)

# Feature: Word count
df['word_count'] = df['Customer Remarks'].astype(str).apply(lambda x: len(x.split()))

# Drop columns that are not useful for ML
df_model = df.drop(['Unique id'], axis=1)

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
from sklearn.feature_selection import SelectKBest, chi2

# Apply on numeric columns only
numeric_cols = df_model.select_dtypes(include=['int64','float64']).columns
X_numeric = df_model[numeric_cols].drop('CSAT Score', axis=1)
y = df_model['CSAT Score']

selector = SelectKBest(score_func=chi2, k=10)
selector.fit(X_numeric, y)

selected_features = X_numeric.columns[selector.get_support()]
selected_features

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# I used Chi-Square for categorical inputs & SelectKBest for numeric impact. This reduces noise and prevents overfitting.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Selected the top features based on Chi-square scores. These features showed the strongest relationship with the target CSAT Score.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?
#
# Yes, transformation is needed to normalize skewed features for better accuracy.

# %%
# Transform Your data
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer()
df_model[numeric_cols] = pt.fit_transform(df_model[numeric_cols])

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_model[numeric_cols])

# %% [markdown]
# ##### Which method have you used to scale you data and why?
#
# I used StandardScaler because it standardizes all numeric features to mean=0 and std=1.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Yes, PCA helps reduce noise & improves training time.”

# %%
# DImensionality Reduction (If needed)
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)  # keep 95% variance
X_pca = pca.fit_transform(scaled_data)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# PCA

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.20, random_state=42)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Used 80-20 split because it provides enough data for training while keeping sufficient test data.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Yes, CSAT Score distribution is imbalanced → used SMOTE to balance.

# %%
# Handling Imbalanced Dataset (If needed)
from imblearn.over_sampling import SMOTE

sm = SMOTE()
X_train, y_train = sm.fit_resample(X_train, y_train)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# I used the SMOTE (Synthetic Minority Oversampling Technique) method to handle the imbalance in the CSAT Score target variable.
# The dataset had fewer samples in certain CSAT categories, which could cause the model to become biased toward the majority class.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 : Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize model
lr = LogisticRegression(max_iter=500)

# Fit the algorithm
lr.fit(X_train, y_train)

# Predict on test data
y_pred_lr = lr.predict(X_test)

# Evaluation metrics
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("\nClassification Report:\n", classification_report(y_test, y_pred_lr))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
# I used Logistic Regression as the baseline model because it is simple, fast, and effective for binary or multi-class classification problems.
#
# The model provided the following performance :
#
# - Accuracy: Measures overall correctness
#
# - Precision: How many predicted positives were correct
#
# - Recall: How many actual positives were captured
#
# - F1-score: Balances precision & recall
#
# - Confusion matrix: Shows class-wise prediction quality
#
# This baseline helps compare and improve future models.”

# %%
# Visualizing evaluation Metric Score chart
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate metric scores
accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr, average='weighted')
recall = recall_score(y_test, y_pred_lr, average='weighted')
f1 = f1_score(y_test, y_pred_lr, average='weighted')

scores = [accuracy, precision, recall, f1]
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

# Plot
plt.figure(figsize=(8,5))
plt.bar(metrics, scores)
plt.title("Evaluation Metrics - Logistic Regression")
plt.ylim(0,1)
plt.ylabel("Score")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs']
}

grid_lr = GridSearchCV(LogisticRegression(max_iter=500), param_grid, cv=5, scoring='accuracy')
grid_lr.fit(X_train, y_train)

best_lr = grid_lr.best_estimator_

print("Best Parameters:", grid_lr.best_params_)
print("Best Score:", grid_lr.best_score_)

# Predict with tuned model
y_pred_lr_tuned = best_lr.predict(X_test)

print("\nTuned Model Accuracy:", accuracy_score(y_test, y_pred_lr_tuned))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV because it systematically tests multiple combinations of parameters and selects the best-performing one based on cross-validation accuracy. This improves model performance and reduces overfitting.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, the tuned Logistic Regression model showed a slight improvement in accuracy and F1-score compared to the baseline model, indicating better generalization and parameter optimization.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
# Decision Tree Classifier is a non-linear model that captures complex relationships in data.
# It handles categorical features well and works even when the dataset contains noise.
# The evaluation metrics show how well the model classifies CSAT classes using accuracy, precision, recall, and F1-score.

# %%
# Visualizing evaluation Metric Score chart
# Calculate metric scores for Decision Tree
accuracy_dt = accuracy_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt, average='weighted')
recall_dt = recall_score(y_test, y_pred_dt, average='weighted')
f1_dt = f1_score(y_test, y_pred_dt, average='weighted')

scores_dt = [accuracy_dt, precision_dt, recall_dt, f1_dt]
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

# Plot bar chart
plt.figure(figsize=(8,5))
plt.bar(metrics, scores_dt)
plt.title("Evaluation Metrics - Decision Tree Classifier")
plt.ylim(0,1)
plt.ylabel("Score")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Initialize model
dt = DecisionTreeClassifier(random_state=42)

# Fit the algorithm
dt.fit(X_train_balanced, y_train_balanced)

# Predict on test data
y_pred_dt = dt.predict(X_test)

# Evaluation metrics
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV because it exhaustively searches all combinations of parameters and finds the best performing ones using cross-validation.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, after tuning, the Decision Tree model showed improved accuracy and F1-score due to better depth and split selection.”

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# - Accuracy:
# Shows overall correctness of the model. Higher accuracy means fewer incorrect predictions, leading to better customer issue handling.
#
# - Precision:
# Shows how many predicted “satisfied/unsatisfied” cases were actually correct.
# High precision means fewer false positives → avoids unnecessary escalations and saves operational cost.
#
# - Recall:
# Shows how many actual dissatisfied customers the model correctly identified.
# High recall is critical because missing unhappy customers can hurt customer retention and brand trust.
#
# - F1-Score:
# Balances precision and recall.
# High F1 means the model is reliable and stable in identifying dissatisfaction without too many wrong alerts.
#
# - Business Impact:
# A model with strong recall & F1 helps Flipkart detect at-risk customers early, improve agent intervention, reduce complaint escalation, and enhance overall customer experience.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize model
rf = RandomForestClassifier(random_state=42)

# Fit the algorithm
rf.fit(X_train_balanced, y_train_balanced)

# Predict on test data
y_pred_rf = rf.predict(X_test)

# Evaluation metrics
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
# Random Forest is an ensemble method that combines multiple decision trees.
# It reduces overfitting, handles imbalanced data well, and gives high accuracy & F1-score.
# It performed better than Logistic Regression and Decision Tree, making it the best model for this CSAT prediction task.

# %%
# Visualizing evaluation Metric Score chart
# Calculate metric scores for Random Forest
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

scores_rf = [accuracy_rf, precision_rf, recall_rf, f1_rf]
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

plt.figure(figsize=(8,5))
plt.bar(metrics, scores_rf)
plt.title("Evaluation Metrics - Random Forest Classifier")
plt.ylim(0,1)
plt.ylabel("Score")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

from sklearn.model_selection import GridSearchCV

param_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10]
}

grid_rf = GridSearchCV(RandomForestClassifier(random_state=42),
                       param_rf, cv=5, scoring='accuracy')

grid_rf.fit(X_train_balanced, y_train_balanced)

best_rf = grid_rf.best_estimator_

print("Best Parameters:", grid_rf.best_params_)

# Predictions with tuned model
y_pred_rf_tuned = best_rf.predict(X_test)

print("Tuned Accuracy:", accuracy_score(y_test, y_pred_rf_tuned))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used because it tests multiple parameter combinations and picks the best one using cross-validation. This improves accuracy and reduces overfitting.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Yes, the tuned Random Forest model showed improved accuracy and F1-score, making it more reliable for predicting customer satisfaction.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# I selected the **Random Forest Classifier** as the final prediction model.
# It outperformed Logistic Regression and Decision Tree in terms of accuracy, recall, and F1-score.
# Random Forest handles nonlinear patterns, reduces overfitting through ensemble learning, and works well with imbalanced datasets.
# After hyperparameter tuning, it delivered the most stable and reliable performance for predicting customer satisfaction (CSAT).

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# ### Final Model Explanation
# The final model used is the **Random Forest Classifier**, an ensemble method that builds multiple decision trees and combines their outputs.
# This makes the model robust, reduces overfitting, and captures complex relationships between features that affect customer satisfaction.
#
# ### Feature Importance
# To understand the model’s decision-making, I analyzed **feature importance scores** generated by the Random Forest algorithm.
# These scores indicate how much each feature contributes to the prediction.
#
# Top important features include:
# - **connected_handling_time** – Longer handling time lowers CSAT.
# - **category** – Some issue categories cause more dissatisfaction.
# - **channel_name** – Satisfaction varies by support channel.
# - **Agent Shift & Tenure Bucket** – Experience and timing affect performance.
# - **Product Category & Item Price** – Product-type issues strongly influence CSAT.
#
# ### Explainability Tool
# I also used **SHAP values** for model explainability.
# SHAP clearly shows how each feature increases or decreases the probability of a customer being satisfied.
# This provides a transparent, business-friendly understanding of why the model makes certain predictions.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import pickle

# Save the best performing model (example: best_rf)
with open("best_model.pkl", "wb") as file:
    pickle.dump(best_rf, file)

print("Model saved successfully!")

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
import pickle

# Load the saved model
with open("best_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# Create a small dummy unseen sample (use any row from X_test)
unseen_sample = X_test.iloc[[0]]   # pick 1 random row for sanity check
prediction = loaded_model.predict(unseen_sample)

print("Prediction on unseen data:", prediction)

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, I successfully built a Machine Learning model to predict customer satisfaction (CSAT) for Flipkart based on customer interactions, agent performance, product details, and operational factors. After performing extensive EDA, data cleaning, feature engineering, and model testing, the Random Forest Classifier emerged as the best-performing model with the highest accuracy, recall, and F1-score.
#
# The tuned Random Forest model demonstrated strong capability in identifying dissatisfied customers, which is essential for improving service quality and customer retention. Feature importance and SHAP analysis provided clear insights into key drivers of satisfaction, such as handling time, issue category, support channel, and agent attributes.
#
# The final model was saved, reloaded, and verified on unseen data, ensuring it is deployment-ready. This model can now be integrated into Flipkart’s support system to proactively detect at-risk customers, optimize agent performance, and improve the overall customer experience.
#
# Overall, the project delivers a scalable, interpretable, and business-impactful ML solution aligned with Flipkart's goal of enhancing customer satisfaction.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
